# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets-semi-colons.txt',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets-semi-colons.txt',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'data.txt']

# %%
df1 = pandas.read_csv("data.txt")
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6ae748db1c61> in <module>
# ----> 1 df1 = pandas.read_csv("data.txt")
#       2 df1
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
df1 = pandas.read_csv("data.txt")
df1
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df1 = pandas.read_csv("data.txt", header=None)
df1
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df1.columns = ["ID", "Address", "City", "ZipCode", "Country","Area", "Rank"]

# %%
df1
# Out:
#    ID          Address           City           ZipCode Country         Area  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Rank
# 0     8
# 1    15
# 2    25
# 3    10
# 4    12
# 5    20

# %%
df1.set_index["ID"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-14eff86c9868> in <module>
# ----> 1 df1.set_index["ID"]
#
# TypeError: 'method' object is not subscriptable

# %%
df1.set_index("ID")
# Out:
#             Address           City           ZipCode Country         Area  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Rank
# ID
# 1      8
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %%
df2 = df1.set_index("ID")

# %%
df2
# Out:
#             Address           City           ZipCode Country         Area  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Rank
# ID
# 1      8
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %%
df1.set_index("ID", inplace="true")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e94f34408a25> in <module>
# ----> 1 df1.set_index("ID", inplace="true")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4271         4 16     10  2014    31
#    4272         """
# -> 4273         inplace = validate_bool_kwarg(inplace, "inplace")
#    4274         if not isinstance(keys, list):
#    4275             keys = [keys]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/util/_validators.py in validate_bool_kwarg(value, arg_name)
#     209     if not (is_bool(value) or value is None):
#     210         raise ValueError(
# --> 211             f'For argument "{arg_name}" expected type bool, received '
# ...

# %%
df1.set_index("ID", inplace=True)

# %%
df1
# Out:
#             Address           City           ZipCode Country         Area  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Rank
# ID
# 1      8
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %%
df1.set_index("Address", inplace= True, drop=False)

# %%
df1
# Out:
#                          Address           City           ZipCode Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Area  Rank
# Address
# 3666 21st St         Madeira     8
# 735 Dolores St   Bready Shop    15
# 332 Hill St      Super River    25
# 3995 23rd St      Ben's Shop    10
# 1056 Sanchez St      Sanchez    12
# 551 Alvarado St   Richvalley    20

# %%
df1.loc["332 Hill St":"551 Alvarado St","Country":"Area"]
# Out:
#                 Country         Area
# Address
# 332 Hill St         USA  Super River
# 3995 23rd St        USA   Ben's Shop
# 1056 Sanchez St     USA      Sanchez
# 551 Alvarado St     USA   Richvalley

# %%
df1.iloc[1:3, 1:2]
# Out:
#                          City
# Address
# 735 Dolores St  San Francisco
# 332 Hill St     San Francisco

# %%
df1
# Out:
#                          Address           City           ZipCode Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Area  Rank
# Address
# 3666 21st St         Madeira     8
# 735 Dolores St   Bready Shop    15
# 332 Hill St      Super River    25
# 3995 23rd St      Ben's Shop    10
# 1056 Sanchez St      Sanchez    12
# 551 Alvarado St   Richvalley    20

# %%
df1.shape[0]
# Out:
# 6

# %%
df1["Continent"] = df1.shape[0]*["North America"]

# %%
df1
# Out:
#                          Address           City           ZipCode Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                         Area  Rank      Continent
# Address
# 3666 21st St         Madeira     8  North America
# 735 Dolores St   Bready Shop    15  North America
# 332 Hill St      Super River    25  North America
# 3995 23rd St      Ben's Shop    10  North America
# 1056 Sanchez St      Sanchez    12  North America
# 551 Alvarado St   Richvalley    20  North America

# %%
type(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fce783c4b89> in <module>
# ----> 1 type(df1)
#
# NameError: name 'df1' is not defined

# %%
df1 = pandas.read_csv("data.txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a34e6975665d> in <module>
# ----> 1 df1 = pandas.read_csv("data.txt")
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
df1 = pandas.read_csv("data.txt")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#    1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 0  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 1  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 2  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 3  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 4  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df1.columns = ["ID", "Address", "City", "ZipCode", "Country","Area", "Rank"]

# %%
df1
# Out:
#    ID          Address           City           ZipCode Country         Area  \
# 0   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 1   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 2   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 3   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 4   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Rank
# 0    15
# 1    25
# 2    10
# 3    12
# 4    20

# %%
df1.set_index("ID", inplace=True, drop=False)

# %%
df1
# Out:
#     ID          Address           City           ZipCode Country         Area  \
# ID
# 2    2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3    3      332 Hill St  San Francisco  California 94114     USA  Super River
# 4    4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5    5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6    6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Rank
# ID
# 2     15
# 3     25
# 4     10
# 5     12
# 6     20

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("735 Dolores St,San Francisco,CA,94119")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
nom.geocode("735 Dolores St,San Francisco,CA,94119")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
nom.geocode("735 Dolores St,San Francisco,CA 94119")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
n = nom.geocode("3995 23rd St,San Francisco, CA 94119")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
n = nom.geocode("3995 23rd St,San Francisco, CA 94119")
n
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.22.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   """Entry point for launching an IPython kernel.

# %%
n = nom.geocode("3995 23rd St,San Francisco, CA 94119")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
n = nom.geocode("3995 23rd St,San Francisco, CA 94119")

# %%
n
# Out:
# Location(3995, 23rd Street, Noe Valley, San Francisco, San Francisco City and County, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
n.lattitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-f92371db1d2a> in <module>
# ----> 1 n.lattitude
#
# AttributeError: 'Location' object has no attribute 'lattitude'

# %%
geopy.location.Location
# Out:
# geopy.location.Location

# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'DataAnalysisWithPandas.ipynb',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'data.txt']

# %%
df1 = pandas.read_csv("supermarkets.csv")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1["Address"] = df1["Address"] + ", " + df1["City"] + ", " + df1["State"] + ", " + df1["Country"]

# %%
df1
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df1["Coordinates"] = df1["Address"].apply(nom.geocode)

# %%
df1
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df1["Latitude"] = df1["Coordinates"].apply(lambda x: x.latitude)

# %%
df1
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df1["Longitude"] = df1["Coordinates"].apply(lamba x: x.longitude if x != None else None)
df1
# Out:
#   File "<ipython-input-36-5d7c8eda6bae>", line 1
#     df1["Longitude"] = df1["Coordinates"].apply(lamba x: x.longitude if x != None else None)
#                                                       ^
# SyntaxError: invalid syntax

# %%
df1["Latitude"] = df1["Coordinates"].apply(lambdaa x: x.latitude if x != None else None)
df1
# Out:
#   File "<ipython-input-37-ff00c8abbe62>", line 1
#     df1["Latitude"] = df1["Coordinates"].apply(lambdaa x: x.latitude if x != None else None)
#                                                        ^
# SyntaxError: invalid syntax

# %%
df1["Latitude"] = df1["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df1["Longitude"] = df1["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df1
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
